# %%
import csv
data = csv.reader(open('./data/201606subway.csv','r'),delimiter=",")

i = int(input('몇시가 궁금하신가요?'))-4
max_person = 0
max_station = ''
for row in data : 
    if(int(max_person) < int(row[2+(i*2)])):
        max_person = row[2+(i*2)]
        max_station = row[1]+'('+ row[0]+')'
print(max_station, max_person)
# Out:
# 몇시가 궁금하신가요?23
# 홍대입구(2호선) 135634

# %%
import csv
data = csv.reader(open('./data/201606subway.csv','r'),delimiter=",")

max_person1 = [0] * 24
max_station1 = [''] * 24

max_person2 = [0] * 24
max_station2 = [''] * 24
for row in data :
    for i in range(24):
        if int(max_person1[i]) < int(row[2+(i*2)]) :
            max_person1[i] = row[2+(i*2)]
            max_station1[i] = row[1] + '/' + str(i+4) #+'('+ row[0]+')'
        if int(max_person2[i]) < int(row[3 + (i * 2)]):
            max_person2[i] = row[3 + (i * 2)]
            max_station2[i] = row[1] + '/' + str(i + 4)  # +'('+ row[0]+')'

for i in range(24):
    print(i+4,'시(승차): ', max_station1[i],'/',max_person1[i])
    print(i + 4,'시(하차): ', max_station2[i], '/', max_person2[i])

import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np
plt.rc('font',family='Malgun Gothic')
cnt = np.arange(24)
plt.subplot(311)
plt.title('2016년 6월 서울시 지하철 시간대별 최다 승차역')
plt.plot(cnt, max_person1,'r')
plt.xticks(cnt, max_station1,rotation='vertical')
plt.ylim(ymax=450000)
plt.subplot(313)
plt.title('2016년 6월 서울시 지하철 시간대별 최다 하차역')
plt.plot(cnt, max_person2,'b')
plt.xticks(cnt, max_station2,rotation='vertical')
plt.ylim(ymax=450000)
plt.show()
# Out:
# 4 시(승차):  구로/4 / 9725
# 4 시(하차):  영등포/4 / 95
# 5 시(승차):  신림/5 / 52427
# 5 시(하차):  강남/5 / 13583
# 6 시(승차):  신림/6 / 96322
# 6 시(하차):  잠실/6 / 82905
# 7 시(승차):  신림/7 / 275615
# 7 시(하차):  강남/7 / 185003
# 8 시(승차):  신림/8 / 356784
# 8 시(하차):  가산디지털단지/8 / 420576
# 9 시(승차):  신림/9 / 201822
# 9 시(하차):  강남/9 / 332767
# 10 시(승차):  신림/10 / 114362
# 10 시(하차):  강남/10 / 171843
# 11 시(승차):  신림/11 / 99065
# 11 시(하차):  강남/11 / 144513
# 12 시(승차):  서울역/12 / 109317
# 12 시(하차):  강남/12 / 142044
# 13 시(승차):  강남/13 / 145787
# 13 시(하차):  강남/13 / 169001
# 14 시(승차):  강남/14 / 144011
# 14 시(하차):  홍대입구/14 / 154672
# 15 시(승차):  강남/15 / 171920
# 15 시(하차):  홍대입구/15 / 156006
# 16 시(승차):  강남/16 / 190786
# 16 시(하차):  홍대입구/16 / 167811
# 17 시(승차):  강남/17 / 234961
# 17 시(하차):  홍대입구/17 / 195469
# 18 시(승차):  강남/18 / 355964
# 18 시(하차):  홍대입구/18 / 253940
# 19 시(승차):  강남/19 / 258275
# 19 시(하차):  신림/19 / 271353
# 20 시(승차):  강남/20 / 206242
# 20 시(하차):  신림/20 / 180909
# 21 시(승차):  강남/21 / 257568
# 21 시(하차):  신림/21 / 174898
# 22 시(승차):  강남/22 / 276057
# 22 시(하차):  신림/22 / 181807
# 23 시(승차):  홍대입구/23 / 135634
# 23 시(하차):  신림/23 / 127618
# 24 시(승차):  강남/24 / 21494
# 24 시(하차):  신림/24 / 40118
# 25 시(승차):  장한평/25 / 19
# 25 시(하차):  서울대입구/25 / 5247
# 26 시(승차):  잠실/26 / 10
# 26 시(하차):  잠실/26 / 9
# 27 시(승차):  을지로입구/27 / 3
# 27 시(하차):  삼성/27 / 10

# %%
import csv
data = csv.reader(open('./data/201606subway.csv','r'),delimiter=",")

인원 = []
역이름 = input('무슨 역인가요?')
호선 = input('몇 호선인가요?')

for row in data :
    if(row[1] == 역이름 and row[0] == 호선):
        print(row[1])
        인원 = row[2:]
    
승차 = 인원[::2]
하차 = 인원[1::2]

print(승차)
print(하차)

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')

labels = []
x = []
for i in range(4,28):
    labels.append(str(i)+'시')
    x.append(i)
    
plt.xticks(x, labels,rotation='vertical')
plt.plot(x,승차,'r', label='승차 인원')
plt.plot(x,하차,'b', label='하차 인원')
plt.ylim(ymax=420000)
plt.title(역이름+'('+호선+')')
plt.legend()
plt.show()
# Out:
# 무슨 역인가요?신도림
# 몇 호선인가요?경부선
# 신도림
# ['295', '1960', '4684', '12685', '14470', '7173', '4987', '4532', '4818', '5207', '4674', '4805', '5351', '7456', '13873', '7730', '6227', '6348', '5118', '2062', '63', '0', '0', '0']
# ['1', '488', '2329', '7268', '17031', '6513', '4436', '4105', '4525', '4931', '4726', '5300', '5963', '7983', '13556', '11619', '6601', '6515', '6240', '3919', '2019', '2', '0', '0']

# %%
import csv
data = csv.reader(open('./data/201606subway.csv','r'),delimiter=",")

인원1 = []
인원2 = []
역이름1 = input('첫 번째 역 이름을 입력하세요 : ')
호선1 = input('첫 번째 역은 몇 호선인가요? : ')
역이름2 = input('두 번째 역 이름을 입력하세요 : ')
호선2 = input('첫 번째 역은 몇 호선인가요? : ')

# %matplotlib inline 

for row in data :
    if(row[1] == 역이름1 and row[0] == 호선1): 
        인원1 = row[2:]
    if(row[1] == 역이름2 and row[0] == 호선2):
        인원2 = row[2:]
    
승차1 = 인원1[::2]
하차1 = 인원1[1::2]

승차2 = 인원2[::2]
하차2 = 인원2[1::2]

import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')

labels = []
x = []
for i in range(4,28):
    labels.append(str(i)+'시')
    x.append(i)
    
plt.xticks(x, labels,rotation='vertical')
plt.plot(x,승차1,'r', label=역이름1+'역 승차')
plt.plot(x,승차2,'b', label=역이름2+'역 승차')
plt.ylim(ymax=420000)
#plt.title(역이름1+'역 승차 인원 vs '+역이름2+'역 승차 인원   # 2016년 6월 티머니카드 제공 데이터')
#plt.legend()
#plt.show()

plt.xticks(x, labels,rotation='vertical')
plt.plot(x,하차1,'r--', label=역이름1+'역 하차')
plt.plot(x,하차2,'b--', label=역이름2+'역 하차')
plt.ylim(ymax=420000)
plt.title(역이름1+'역 승하차 인원 vs '+역이름2+'역 승하차 인원   # 2016년 6월 티머니카드 제공 데이터')
plt.legend()
plt.show()
# Out:
# 첫 번째 역 이름을 입력하세요 : 신림
# 첫 번째 역은 몇 호선인가요? : 2호선
# 두 번째 역 이름을 입력하세요 : 강남
# 첫 번째 역은 몇 호선인가요? : 2호선
